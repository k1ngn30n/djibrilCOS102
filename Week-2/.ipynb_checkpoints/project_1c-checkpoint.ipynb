# %% [markdown]
# START
# SET Name1 = "Jane"
# SET Jane_Age = 19
#
# SET Name2 = "Brian"
# SET Brian_Age = 18
#
# DISPLAY = Name1 + " is " + Jane_Age
# DISPLAY = Name2 + " is " + Brian_Age
#
# SET Temp_Age = Jane_Age
#
# SET Jane_Age = Brian_Age
#
# SET Brian_Age = Temp_Age
#
# DISPLAY = Name1 + "is currently"  + Jane_Age
# DISPLAY = Name2 + "is currently"  + Brian_Age
# END

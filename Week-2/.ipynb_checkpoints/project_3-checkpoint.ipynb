# %% [markdown]
# START
#
# SET Girls_Data = [
#         ["Evelyn", 17, 5.5, 80], ["Jessica", 16, 6.0, 85], ["Somto", 17, 5.4, 70],
#         ["Edith", 18, 5.9, 60], ["Liza", 16, 5.6, 76], ["Madonna", 18, 5.5, 66],
#         ["Waje", 17, 6.1, 87], ["Tola", 20, 6.0, 95], ["Aisha", 19, 5.7, 50], ["Latifa", 17, 5.5, 49]
#     ]
#
#  SET Boys_Data = [
#         ["Chinedu", 19, 5.7, 74], ["Liam", 16, 5.9, 87], ["Wale", 18, 5.8, 75],
#         ["Gbenga", 17, 6.1, 68], ["Abiola", 20, 5.9, 66], ["Kola", 19, 5.5, 78],
#         ["Kunle", 16, 6.1, 87], ["George", 18, 5.4, 98], ["Thomas", 17, 5.8, 54], ["Wesley", 19, 5.7, 60]
#     ]
#
#  ASSIGN (Girls_Data + Boys_Data) TO All_Students
#
# DISPLAY "Name         | Age   | Height   | Score"
#     DISPLAY "----------------------------------------"
#
# FOR EACH Student IN All_Students DO
#         // Extract individual attributes
#         SET Current_Name = Student[0]
#         SET Current_Age = Student[1]
#         SET Current_Height = Student[2]
#         SET Current_Score = Student[3]
#
# DISPLAY Current_Name, Current_Age, Current_Height, Current_Score
#     END FOR
#
# END

# %%
def student_table():
    girls = [
        ["Evelyn", 17, 5.5, 80], ["Jessica", 16, 6.0, 85], ["Somto", 17, 5.4, 70],
        ["Edith", 18, 5.9, 60], ["Liza", 16, 5.6, 76], ["Madonna", 18, 5.5, 66],
        ["Waje", 17, 6.1, 87], ["Tola", 20, 6.0, 95], ["Aisha", 19, 5.7, 50], ["Latifa", 17, 5.5, 49]
    ]
    
    boys = [
        ["Chinedu", 19, 5.7, 74], ["Liam", 16, 5.9, 87], ["Wale", 18, 5.8, 75],
        ["Gbenga", 17, 6.1, 68], ["Abiola", 20, 5.9, 66], ["Kola", 19, 5.5, 78],
        ["Kunle", 16, 6.1, 87], ["George", 18, 5.4, 98], ["Thomas", 17, 5.8, 54], ["Wesley", 19, 5.7, 60]
    ]

    all_students = girls + boys

    print(f"{'Name':<12} | {'Age':<5} | {'Height':<8} | {'Score':<6}")
    print("-" * 40)

    for student in all_students:
        name, age, height, score = student
        print(f"{name:<12} | {age:<5} | {height:<8} | {score:<6}")

student_table()

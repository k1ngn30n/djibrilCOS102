# %%
import numpy as np

def solve_equation():
    print("--- Equation Root Solver ---")
    print("1. Quadratic (ax^2 + bx + c = 0)")
    print("2. Cubic (ax^3 + bx^2 + cx + d = 0)")
    print("3. Quartic (ax^4 + bx^3 + cx^2 + dx + e = 0)")
    
    choice = input("Enter the number of your choice (1-3): ")

    if choice == '1':
        a = float(input("Enter a: "))
        b = float(input("Enter b: "))
        c = float(input("Enter c: "))
        coeffs = [a, b, c]
    elif choice == '2':
        a = float(input("Enter a: "))
        b = float(input("Enter b: "))
        c = float(input("Enter c: "))
        d = float(input("Enter d: "))
        coeffs = [a, b, c, d]
    elif choice == '3':
        a = float(input("Enter a: "))
        b = float(input("Enter b: "))
        c = float(input("Enter c: "))
        d = float(input("Enter d: "))
        e = float(input("Enter e: "))
        coeffs = [a, b, c, d, e]
    else:
        print("Invalid choice!")
        return

    roots = np.roots(coeffs)
    
    print("\nThe roots are:")
    for i, root in enumerate(roots, 1):
        print(f"Root {i}: {root}")

solve_equation()
# Out:
# --- Equation Root Solver ---
# 1. Quadratic (ax^2 + bx + c = 0)
# 2. Cubic (ax^3 + bx^2 + cx + d = 0)
# 3. Quartic (ax^4 + bx^3 + cx^2 + dx + e = 0)
# Enter the number of your choice (1-3):  2
# Enter a:  4
# Enter b:  1
# Enter c:  3
# Enter d:  3
# The roots are:
# Root 1: (0.2262003539775918+1.0082658267577846j)
# Root 2: (0.2262003539775918-1.0082658267577846j)
# Root 3: (-0.7024007079551837+0j)
